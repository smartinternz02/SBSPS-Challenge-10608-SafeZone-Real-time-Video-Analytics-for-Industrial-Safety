# %%
import os
from IPython.display import Image, display
from IPython import display

# %%
HOME = os.getcwd()
HOME
# Out:
# '/content'

# %%
# !pip install ultralytics==8.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.8 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=86e2a8ad8ca7fd59580aef3fdf21696569dbda93cdbdadc8ce421844fe089b84
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets

# %%
# !pwd
# Out:
# /content

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pwd
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2BwAkoBpeBbbLrjr7hWC")
project = rf.workspace("explore-mtqut").project("safezone")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.3/59.3 kB 4.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=71f376c22e9231b72d2d63af93828c064aa6cb895a60c6288dfcd245625ebf51
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
# ...

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {dataset.location}
# Out:
# /content/datasets/Safezone-2

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/Safezone-2/data.yaml epochs=70 imgsz=640  v5loader=True
# Out:
# /content
# ...

# %%
# !ls /content/drive/MyDrive/train2
# Out:
# args.yaml					    train_batch17580.jpg
# confusion_matrix.png				    train_batch17581.jpg
# events.out.tfevents.1692691920.ef0b90169fad.1334.0  train_batch17582.jpg
# F1_curve.png					    train_batch1.jpg
# P_curve.png					    train_batch2.jpg
# PR_curve.png					    val_batch0_labels.jpg
# predictions.json				    val_batch0_pred.jpg
# R_curve.png					    val_batch1_labels.jpg
# results.csv					    val_batch1_pred.jpg
# results.png					    weights
# train_batch0.jpg

# %%
Image(filename='/content/drive/MyDrive/train2/confusion_matrix.png', width=900)

# %%
Image(filename='/content/drive/MyDrive/train2/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/train2/val_batch0_labels.jpg', width=600)

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/train2/weights/best.pt conf=0.25 source=/content/datasets/Safezone-2/test/images/402-4029732_burglar-mask-transparent-background-hd-png-download_png.rf.a9e4051a192382e49bc285041550dc0c.jpg
# Out:
# 2023-08-22 12:03:16.772700: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 12:03:18.015124: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25845550 parameters, 0 gradients, 78.7 GFLOPs
# image 1/1 /content/datasets/Safezone-2/test/images/402-4029732_burglar-mask-transparent-background-hd-png-download_png.rf.a9e4051a192382e49bc285041550dc0c.jpg: 640x640 1 Robber-Mask, 37.0ms
# Speed: 0.6ms pre-process, 37.0ms inference, 115.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
Image("/content/runs/detect/predict/402-4029732_burglar-mask-transparent-background-hd-png-download_png.rf.a9e4051a192382e49bc285041550dc0c.jpg")

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/train2/weights/best.pt conf=0.25 source=/content/datasets/Safezone-2/test/images/people-1298-_jpg.rf.0204ba116b24fa4a28b5efaa2624aaab.jpg
# Out:
# 2023-08-22 12:05:11.830662: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 12:05:12.876510: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25845550 parameters, 0 gradients, 78.7 GFLOPs
# image 1/1 /content/datasets/Safezone-2/test/images/people-1298-_jpg.rf.0204ba116b24fa4a28b5efaa2624aaab.jpg: 640x640 1 Fall-Detected, 37.0ms
# Speed: 0.6ms pre-process, 37.0ms inference, 110.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
Image("/content/runs/detect/predict2/people-1298-_jpg.rf.0204ba116b24fa4a28b5efaa2624aaab.jpg")
